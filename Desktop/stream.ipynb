# %%
""" As of now this file is an infinite loop that never stops,
    maybe thats a good thing, maybe it's a bad thing. (Probs bad)
    Limitation right now: links at the end and I'm not happy with cleaning
    And the tweet so long that it links it is still an issue
"""

from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
#from api_info import * # api_key, api_secret, access_token, access_secret
import json
import datetime
import os
import re

ticker = "TSLA" # need to figure out more keywords for the filter, e.g. tesla

f = open(f"{ticker}.csv", "a")
if os.path.getsize(f"{ticker}.csv") == 0: # creates title if file empty
  f.write("Time, Text\n")


def clean_text(text):
  """ Gets rid of punctuation and links, still need to work on this
  """
  text = text.lower()
  text = re.sub(r"http\S+", "", text)
  text = re.sub(r'[^a-z0-9 ]+', '', text)
  return text


class listener(StreamListener):
  """ This class outputs any tweet based on a keyword as soon
      as it's posted.
  """

  def on_data(self, data):
    """ This function converts the tweet string into a python dictonary
        then outputs it to the terminal.
    """
    
    tweet = json.loads(data)["text"] #  convert data into a python dictionary

    date = str(datetime.datetime.now()) # convert date to a string
    f.write(date + ", " + clean_text(tweet)+"\n")
    f.flush()
    return True

  def on_error(self, status):
    print(status) #  just tells us what the error is

auth = OAuthHandler(api_key, api_secret) #  this just sets up the api for us to use
auth.set_access_token(access_token, access_secret)

twitterStream = Stream(auth, listener(), tweet_mode="extended")
twitterStream.filter(languages=["en"], track=[ticker]) #  this runs the class while filtering for english and the keyword
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-8753f8ecbafb> in <module>()
#      52
#      53 twitterStream = Stream(auth, listener(), tweet_mode="extended")
# ---> 54 twitterStream.filter(languages=["en"], track=[ticker]) #  this runs the class while filtering for english and the keyword
#      55 f.close()
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# ...
